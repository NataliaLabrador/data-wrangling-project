# %%
# Install and import necessary libraries
# !pip install spotipy
# !pip install pylast
import requests
import pandas as pd
import numpy as np
import pylast

# %%
# Set my credentials
CLIENT_ID = "9f8fa04c80a94cbc99b0190449fe7374"
CLIENT_SECRET = "0169432afd76420a8b992fd89788610b"

# %%
# Import spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %%
# Import CSV file with the cleaned DataFrame
songs_apis_df = pd.read_csv('songs_df.csv')

# %%
songs_apis_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts        streams  in_apple_playlists  ...  key   mode  \
# ...

# %% [markdown]
# # Add new variables

# %% [markdown]
# ## Column album

# %%
# Create a function to obtain the album of each song based on its id
def get_album(track_id):
    try:
        # Obtenain information of each song
        track_info = sp.track(track_id)
        # Get album name
        album_name = track_info['album']['name']
        return album_name
    except:
        return None

# Create a column called album and apply the function to every row in the track_id column
songs_apis_df['album'] = songs_apis_df['track_id'].apply(get_album)

# %%
songs_apis_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts        streams  in_apple_playlists  ...   mode  \
# ...

# %% [markdown]
# ## Column duration

# %%
# Create a function to obtain the duration of each song based on its id
def get_duration(track_id):
    try:
        # Obtain the information of each song
        track_info = sp.track(track_id)
        # Obtain the duration of each song
        duration_ms = track_info['duration_ms']
        # Convert the duration into seconds 
        duration_sec = duration_ms / 1000
        return duration_sec
    except:
        return None

# Create a column called duration and apply the function to every row in the track_id column
songs_apis_df['duration'] = songs_apis_df['track_id'].apply(get_duration)

# %%
songs_apis_df.head()

# %% [markdown]
# ## Column my_playlist
